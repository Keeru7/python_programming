# %%
#f strings

# %%
firstname = 'keerthana'
lastname = 'martha'
message =  f"You can give your message"
fullname = f"{firstname}{lastname}"
print(message)
print(fullname)
# Out:
# You can give your message
# keerthanamartha

# %%
#removing whitespaces from strings

# %%
name = '  keerthana'
name.lstrip()
# Out:
# 'keerthana'

# %%
print(len(firstname))
# Out:
# 9

# %% [raw]
# #len of the string

# %%
print(len(fullname))
# Out:
# 15

# %%
# Concatenation of two stings

# %%
country = "India"
state = "Telangana"
details = country + " " + state
print(details)
# Out:
# India Telangana

# %%
print(type(details))
# Out:
# <class 'str'>

# %%
print(country[0])
# Out:
# I

# %%
# uppercase

# %%
name = 'keerthana'
print(name.upper())
# Out:
# KEERTHANA
